# %%
import numpy as np
import pandas as pd

# %%
# dc dataframe
df_old = pd.read_csv(r'Data\912200790272310.11-24.13h55ph51.csv')
df_new = pd.read_csv(r'Data\daiphatthanh.sound.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\projects\python\data analyze\final_project\concatData.ipynb Cell 2 line 2
#       <a href='vscode-notebook-cell:/d%3A/projects/python/data%20analyze/final_project/concatData.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # dc dataframe
# ----> <a href='vscode-notebook-cell:/d%3A/projects/python/data%20analyze/final_project/concatData.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df_old = pd.read_csv(r'Data\912200790272310.11-24.13h55ph51.csv')
#       <a href='vscode-notebook-cell:/d%3A/projects/python/data%20analyze/final_project/concatData.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> df_new = pd.read_csv(r'Data\daiphatthanh.sound.csv')
#
# ...

# %%
df_new['post_text'].to_list()
# Out:
# ['KHOẢNH KHẮC SƠN TÙNG M-TP MỪNG SINH NHẬT LẦN THỨ 11 CÙNG SKY \U0001fa75\n\nTrên nền nhạc “Như Ngày Hôm Qua”, Sơn Tùng M-TP đã cùng ôn lại kỉ niệm xuyên suốt 11 năm làm nghề và nhận được sự ủng hộ từ SKY. Sơn Tùng chia sẻ,See more với anh SKY như một gia đình thứ 2, luôn bên cạnh tin tưởng, ủng hộ, bảo vệ anh ngay cả trong những giai đoạn khó khăn nhất.',
#  'SƠN TÙNG M-TP MƯỢN SÂN KHẤU HÔM NAY ĐỂ CHÚC MỪNG SINH NHẬT LẦN THỨ 11 CÙNG SKY.\n\nSơn Tùng gửi đến SKY - những người đã ở bên cạnh anh trong suốt 11 năm qua, những người anh xem như gia đình thứ 2 lời tri ân chân thành vì đã luôn ủng hộ, bảo vệ tấm thân nhỏ bé của anh ngay cả trong những giai đoạn khó khăn nhất.',
#  'Mời các bạn ăn cơm tró lúc 11h đêm với "Hà Nội" tới từ Obito và VSTRA trong màn trình diễn tối nay tại 2IN1 CONCERT.',
#  'Nếu như em gặp anh\nLúc hai ta đã trưởng thành\n\n#ChiDepDapGioReSong #ChiDepDapGioReSong2023 #ChiDep #DapGio',
# ...

# %%
# a = bài cuối của dataframe mới nhất ko lỗi
# xóa các dòng của dataframe cũ từ bài a 
# thực hiện nối từ đấy.
display(
    df_old[df_old['post_text'] == 'SNOOP DOGG SẼ THÔI HẤT CÙN\n\nHình ảnh mới nhất trên trang cá nhân Snoop Dogg cho biết sau rất nhiều cuộc trò chuyện và cân nhắc với gia đình, nam rapper đã quyết định bỏ sà cân.\n\nHy vọng rằng anh sẽ làm được!']
)
# Out:
#             post_id                                               text  \
# 86  908596983966024  SNOOP DOGG SẼ THÔI HẤT CÙN\n\nHình ảnh mới nhấ...
#
#                                             post_text shared_text  \
# 86  SNOOP DOGG SẼ THÔI HẤT CÙN\n\nHình ảnh mới nhấ...         NaN
#
#     original_text                 time     timestamp  \
# 86            NaN  2023-11-17 14:07:53  1.700205e+09
#
#                                                 image  \
# 86  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
#
#                                      image_lowquality  \
# 86  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
#
#                                                images  ... reaction_count  \
# 86  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...  ...           6029
#
#    with          page_id sharers      image_id            image_ids  \
# 86  NaN  905871509607608     NaN  9.085962e+14  ['908596217299434']
#
# ...

# %%
# xóa từ bài ) đến bài 86 của đata cũ
# nối data mới vào data cũ đã được xóa bài trùng lặp .
ls = []
for i in range(0,87):
    ls.append(i)
data = pd.DataFrame(data=df_old)
res = data.drop(ls,axis='index')
res
# Out:
#              post_id                                               text  \
# 87   908555020636887  Vào 10 năm trước, ngày 12/11/2013, bản tin thờ...
# 88   908543550638034     Cuối cùng cũng đến hẹn.\n\nẢnh: Phim Sắp Chiếu
# 89   908313050661084  Như chia sẻ của Đen trước đó, toàn bộ doanh th...
# 90   908305730661816  Những ngày cuối năm, trời bắt đầu trở lạnh cùn...
# 91   908248014000921  TAYNGUYENSOUND PLAYLIST: NHỮNG CA KHÚC SẼ ĐƯỢC...
# ..               ...                                                ...
# 143  906122894213433  Mùa 1 The Masked Singer có ‘Anh Thương Em Đến ...
# 144  906132410879148  Có một Việt Nam cổ kính, hoài niệm cùng chuyện...
# 145  906147284210994  Nguyên Hà trở lại với sản phẩm mới mang tên "N...
# 146  906040377555018  Chị đẹp HyunA “xả ảnh”, khoe những món quà đán...
# 147  906017847557271  Bác Nguyễn Ngọc Giao là bố của Nodey - chồng S...
#
#                                              post_text shared_text  \
# ...

# %%
newData = pd.concat([df_new, res], axis=0,ignore_index=True)
newData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        175 non-null    int64
#  1   text                           174 non-null    object
#  2   post_text                      174 non-null    object
#  3   shared_text                    0 non-null      object
#  4   original_text                  0 non-null      float64
#  5   time                           175 non-null    object
#  6   timestamp                      175 non-null    float64
#  7   image                          125 non-null    object
#  8   image_lowquality               175 non-null    object
#  9   images                         175 non-null    object
#  10  images_description             175 non-null    object
#  11  images_lowquality              175 non-null    object
# ...

# %%
newData
# Out:
#              post_id                                               text  \
# 0    912937063532016  KHOẢNH KHẮC SƠN TÙNG M-TP MỪNG SINH NHẬT LẦN T...
# 1    912919293533793  SƠN TÙNG M-TP MƯỢN SÂN KHẤU HÔM NAY ĐỂ CHÚC MỪ...
# 2    912916456867410  Mời các bạn ăn cơm tró lúc 11h đêm với "Hà Nội...
# 3    912832070209182  Nếu như em gặp anh\nLúc hai ta đã trưởng thành...
# 4    912905323535190  Khoảnh khắc Tez gửi lời tri ân đến Pháo ngay t...
# ..               ...                                                ...
# 170  906122894213433  Mùa 1 The Masked Singer có ‘Anh Thương Em Đến ...
# 171  906132410879148  Có một Việt Nam cổ kính, hoài niệm cùng chuyện...
# 172  906147284210994  Nguyên Hà trở lại với sản phẩm mới mang tên "N...
# 173  906040377555018  Chị đẹp HyunA “xả ảnh”, khoe những món quà đán...
# 174  906017847557271  Bác Nguyễn Ngọc Giao là bố của Nodey - chồng S...
#
#                                              post_text shared_text  \
# ...

# %%
newData['reactios']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\projects\python\data analyze\final_project\concatData.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/projects/python/data%20analyze/final_project/concatData.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> newData['reactios']
#
# NameError: name 'newData' is not defined

# %%
display(
    newData['reactions'].isna().value_counts(),
    newData['reactors'].isna().value_counts(),
    newData['comments'].isna().value_counts(),
    newData['comments_full'].isna().value_counts(),
    newData['reaction_count'].isna().value_counts(),
    newData['shares'].isna().value_counts(),
    newData['images_description'].isna().value_counts()
)
# Out:
# reactions
# False    175
# Name: count, dtype: int64
# reactors
# False    175
# Name: count, dtype: int64
# comments
# False    175
# Name: count, dtype: int64
# comments_full
# False    175
# Name: count, dtype: int64
# reaction_count
# False    175
# Name: count, dtype: int64
# shares
# False    175
# Name: count, dtype: int64
# images_description
# False    175
# Name: count, dtype: int64

# %%
FANPAGE_LINK ="Data_26-11"
FOLDER_PATH = r"Data/"
path=FOLDER_PATH + FANPAGE_LINK + ".csv"

# %%
newData.to_csv(path, index=False)
print(path)
# Out:
# Data/Data_26-11.csv
