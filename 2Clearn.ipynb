# %% [markdown]
# <img src="https:////scontent.fhan9-1.fna.fbcdn.net/v/t39.30808-6/339122927_1347965006053141_1323654940389313527_n.jpg?_nc_cat=1&ccb=1-7&_nc_sid=5f2048&_nc_ohc=RxgK2wQBdfIAX9RQ12B&_nc_ht=scontent.fhan9-1.fna&oh=00_AfBOx5rlfgrGYgo-aGWT946hcP3U0n2WBaCcYTFM6OyZww&oe=65506ED3"
#     style="width:500px; float: right; margin: 0 40px 40px 40px;"></img>
#
# ##  PHÂN TÍCH DỮ LIỆU PAGE [đài phát thanh](https://www.facebook.com/daiphatthanh.sound)
# ## Bài phân viết phân tích page được viết trong [NOTION](https://www.notion.so/Data-Analyze-Page-Facebook-6ba0209824a04832b291f084f583f6b9).
#
# [hướng dẫn viết markdown](https://www.markdowntutorial.com/lesson/3/)
# Làm sạch dữ liệu: Dữ liệu thu thập ở bước 2 thường chứa nhiều khuyết thiếu
# đến từ lỗi của công cụ thu thập hay bản thân bài đăng trên Fanpage (chẳng
# hạn bài đăng không chứa nội dung, chưa có bình luận, hạn chế quyền truy cập
# bởi token, . . . ). Do vậy, sinh viên cần xem xét dữ liệu thô mình đã thu thập
# để loại bỏ đi các thông tin không liên quan hoặc không cần thiết trong bộ dữ
# liệu.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Import thư viện và data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv('Data\daiphatthanh.sound1.csv')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Raw dataframe
# đây là dữ liệu thô chưa được xử lý.

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        150 non-null    int64
#  1   text                           147 non-null    object
#  2   post_text                      147 non-null    object
#  3   shared_text                    1 non-null      object
#  4   original_text                  0 non-null      float64
#  5   time                           150 non-null    object
#  6   timestamp                      150 non-null    int64
#  7   image                          90 non-null     object
#  8   image_lowquality               150 non-null    object
#  9   images                         150 non-null    object
#  10  images_description             150 non-null    object
#  11  images_lowquality              150 non-null    object
# ...

# %% [markdown]
# - sẽ chọn lấy colws mà có giá trị null < 50 :
# 'post_id','text','post_text','time','timestamp','image_lowquality','images','images_description',
#        'images_lowquality','images_lowquality_description','comments','shares',
#        'post_url','links','user_id','username','user_url','is_live','available','comments_full',
#        'reactors','w3_fb_url','reactions','reaction_count','page_id','image_ids',
#        'was_live','fetched_time'

# %%
raw_df.describe() # giá trị này sẽ ko chuẩn vì data chưa được xử lý.
# Out:
#             post_id  original_text     timestamp  video_duration_seconds  \
# count  1.500000e+02            0.0  1.500000e+02                     0.0
# mean   9.043274e+14            NaN  1.699631e+09                     NaN
# std    1.009599e+13            NaN  2.408988e+05                     NaN
# min    7.827899e+14            NaN  1.699246e+09                     NaN
# 25%    9.038548e+14            NaN  1.699441e+09                     NaN
# 50%    9.053881e+14            NaN  1.699672e+09                     NaN
# 75%    9.061300e+14            NaN  1.699794e+09                     NaN
# max    9.077563e+14            NaN  1.700061e+09                     NaN
#
#        video_height      video_id  video_quality  video_size_MB  \
# count           0.0  5.900000e+01            0.0            0.0
# mean            NaN  1.042916e+15            NaN            NaN
# std             NaN  9.786652e+14            NaN            NaN
# ...

# %%
raw_df.isnull()
# Out:
#      post_id   text  post_text  shared_text  original_text   time  timestamp  \
# 0      False  False      False         True           True  False      False
# 1      False  False      False         True           True  False      False
# 2      False  False      False         True           True  False      False
# 3      False  False      False         True           True  False      False
# 4      False  False      False         True           True  False      False
# ..       ...    ...        ...          ...            ...    ...        ...
# 145    False  False      False         True           True  False      False
# 146    False  False      False         True           True  False      False
# 147    False  False      False         True           True  False      False
# 148    False  False      False         True           True  False      False
# 149    False  False      False         True           True  False      False
#
# ...

# %% [markdown]
# dữ liệu được lấy từ ngày.

# %%
raw_df['time']
# Out:
# 0      2023-11-15 22:02:13
# 1      2023-11-15 21:30:56
# 2      2023-11-15 20:32:56
# 3      2023-11-15 20:06:52
# 4      2023-11-15 19:38:51
#               ...
# 145    2023-11-06 15:38:10
# 146    2023-11-06 14:47:05
# 147    2023-11-06 12:59:07
# 148    2023-11-06 12:32:13
# 149    2023-11-06 11:49:01
# Name: time, Length: 150, dtype: object

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Handling Missing Data with Pandas

# %% [markdown]
# data = các cột có dữ liệu là non null >= 100

# %%
data = pd.DataFrame(raw_df[['post_id','text','post_text','time','timestamp','image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description','comments','shares',
       'post_url','links','user_id','username','user_url','is_live','available','comments_full',
       'reactors','w3_fb_url','reactions','reaction_count','page_id','image_ids',
       'was_live','fetched_time']])
data
# Out:
#              post_id                                               text  \
# 0    907756300716759  Vũ Trụ Người Nhện của Sony chào đón phim dành ...
# 1    907691994056523  Khi Từng Quen còn chưa hết hot và Bé Ơi Từ Từ ...
# 2    907708237388232  Ca khúc có giai điệu cực đáng iu cho mùa noel ...
# 3    907705917388464  Về miền tây ăn đám cưới miệt vườn của Gin Tuấn...
# 4    907693637389692  Outfit chuẩn bị ăn cưới miệt vườn của Puka - G...
# ..               ...                                                ...
# 145  902924821199907  KẾT QUẢ TEST NHANH CỦA G-DRAGON VỚI MAI THUÝ: ...
# 146  902903497868706  LOW G ĐỘC ĐÁO QUA PHIÊN BẢN PIXEL ART\n\nTại G...
# 147  902873047871751  Khi mới được nắm tay cờ rút nhưng đã nghĩ đến ...
# 148  902864724539250  Obito cùng SHIKI thể hiện track Tell The Kids ...
# 149  902850977873958  G-DRAGON trình diện để hợp tác điều tra vụ việ...
#
#                                              post_text                 time  \
# ...

# %% [markdown]
# Cac du lieu lien quan den uses la nhu nhau trong moi bai post.
# - suy ra ko can thiet lay

# %%
data[['username','user_id','user_url']]
# Out:
#             username          user_id  \
# 0    Đài Phát Thanh.  100044471918044
# 1    Đài Phát Thanh.  100044471918044
# 2    Đài Phát Thanh.  100044471918044
# 3    Đài Phát Thanh.  100044471918044
# 4    Đài Phát Thanh.  100044471918044
# ..               ...              ...
# 145  Đài Phát Thanh.  100044471918044
# 146  Đài Phát Thanh.  100044471918044
# 147  Đài Phát Thanh.  100044471918044
# 148  Đài Phát Thanh.  100044471918044
# 149  Đài Phát Thanh.  100044471918044
#
#                                               user_url
# 0    https://facebook.com/daiphatthanh.sound?lst=10...
# 1    https://facebook.com/daiphatthanh.sound?lst=10...
# 2    https://facebook.com/daiphatthanh.sound?lst=10...
# 3    https://facebook.com/daiphatthanh.sound?lst=10...
# 4    https://facebook.com/daiphatthanh.sound?lst=10...
# ..                                                 ...
# 145  https://facebook.com/daiphatthanh.sound?eav=Af...
# 146  https://facebook.com/daiphatthanh.sound?eav=Af...
# ...

# %% [markdown]
# Du lieu ve image
# - day la thong tin quan trong

# %%
data[['image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description']]
# Out:
#                                       image_lowquality  \
# 0    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 1    https://scontent.fhan2-4.fna.fbcdn.net/v/t15.5...
# 2    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 3    https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 4    https://scontent.fhan2-4.fna.fbcdn.net/v/t39.3...
# ..                                                 ...
# 145  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 146  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 147  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 148  https://scontent.fhan2-4.fna.fbcdn.net/v/t15.5...
# 149  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
#
#                                                 images  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
# ...

# %%
data['images_description'].iloc[7]
# Out:
# '["Có thể là hình ảnh về 1 người, tóc mái và văn bản cho biết \'ĐÀIPHÁT PHÁT THANH. BRAND BRAND PHẢ MỞ LẠI PRE-ORDER vì QUÁ NHIỀU NGƯỜI YÊU CẦU MUA MẪU KÍNH GIỐNG G-DRAGON /daiphatthanh.\'"]'

# %% [markdown]
# is live

# %%
data['is_live'].count
# khong can thiet lay
# Out:
# <bound method Series.count of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: is_live, Length: 150, dtype: bool>

# %%
display(
    data.shape,
    data.dtypes
)
# Out:
# (150, 28)
# post_id                           int64
# text                             object
# post_text                        object
# time                             object
# timestamp                         int64
# image_lowquality                 object
# images                           object
# images_description               object
# images_lowquality                object
# images_lowquality_description    object
# comments                          int64
# shares                            int64
# post_url                         object
# links                            object
# user_id                           int64
# username                         object
# user_url                         object
# is_live                            bool
# available                          bool
# comments_full                    object
# reactors                         object
# w3_fb_url                        object
# reactions                        object
# ...

# %% [markdown]
# Vì yêu cầu đề bài là lấy 100 bài. Mà data đã có đủ nên không cần xử lý nhiều
# Trực tiếp lấy dữ liệu các dòng có thể dùng được.

# %%
df = pd.DataFrame(data= data.dropna(how='any'))
df
# Out:
#              post_id                                               text  \
# 0    907756300716759  Vũ Trụ Người Nhện của Sony chào đón phim dành ...
# 1    907691994056523  Khi Từng Quen còn chưa hết hot và Bé Ơi Từ Từ ...
# 2    907708237388232  Ca khúc có giai điệu cực đáng iu cho mùa noel ...
# 3    907705917388464  Về miền tây ăn đám cưới miệt vườn của Gin Tuấn...
# 4    907693637389692  Outfit chuẩn bị ăn cưới miệt vườn của Puka - G...
# ..               ...                                                ...
# 111  903953911096998  THÙY TIÊN DẠO NÀY: COSPLAY CAROL DANVERS, KHOE...
# 112  903943584431364  CHIẾC BMW TRỊ GIÁ HƠN 4 TỎI ĐƯA G-DRAGON ĐẾN T...
# 113  903846634441059  Talkshow chuyện nhà hot gơn Tây Hồ, vẫn là chủ...
# 114  903783757780680  ĐỘC LẠ DOUYIN TRUNG HOA\n\n"Chàng trai Trung Q...
# 115  903580357801020  HÃY TRÂN TRỌNG CÔ GÁI Ở BÊN CẠNH BẠN KHI BẠN K...
#
#                                              post_text                 time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115 entries, 0 to 115
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        115 non-null    int64
#  1   text                           115 non-null    object
#  2   post_text                      115 non-null    object
#  3   time                           115 non-null    object
#  4   timestamp                      115 non-null    int64
#  5   image_lowquality               115 non-null    object
#  6   images                         115 non-null    object
#  7   images_description             115 non-null    object
#  8   images_lowquality              115 non-null    object
#  9   images_lowquality_description  115 non-null    object
#  10  comments                       115 non-null    int64
#  11  shares                         115 non-null    int64
# ...

# %% [markdown]
# Kiểm tra số lượng tương tác trong nhưng bài mới đăng tải
# - vì số lượng người tương tác ko ổn định

# %%
df[['post_id','time','reactions','comments','shares','reactors']]
# Out:
#              post_id                 time  \
# 0    907756300716759  2023-11-15 22:02:13
# 1    907691994056523  2023-11-15 21:30:56
# 2    907708237388232  2023-11-15 20:32:56
# 3    907705917388464  2023-11-15 20:06:52
# 4    907693637389692  2023-11-15 19:38:51
# ..               ...                  ...
# 111  903953911096998  2023-11-08 18:24:26
# 112  903943584431364  2023-11-08 17:56:14
# 113  903846634441059  2023-11-08 12:34:41
# 114  903783757780680  2023-11-08 09:30:34
# 115  903580357801020  2023-11-07 22:51:39
#
#                                              reactions  comments  shares  \
# 0                        {'thích': 11, 'yêu thích': 2}         0       0
# 1    {'thích': 887, 'yêu thích': 402, 'haha': 3, 'w...        26      36
# 2    {'thích': 180, 'yêu thích': 52, 'haha': 1, 'th...        16       7
# 3    {'thích': 8236, 'yêu thích': 260, 'haha': 3898...       329      43
# 4    {'thích': 2235, 'yêu thích': 26, 'haha': 2289,...        60       7
# ...

# %% [markdown]
# Kiểm tra các bài viết trùng lặp

# %%
# xoa gia tri trung lap neu co
# df1.drop_duplicates().count()

# %% [markdown]
# [['username','user_id','user_url']]

# %%
df[['username','user_id','user_url']]
# du lieu nhu nhau khong can thiet
# Out:
#             username          user_id  \
# 0    Đài Phát Thanh.  100044471918044
# 1    Đài Phát Thanh.  100044471918044
# 2    Đài Phát Thanh.  100044471918044
# 3    Đài Phát Thanh.  100044471918044
# 4    Đài Phát Thanh.  100044471918044
# ..               ...              ...
# 111  Đài Phát Thanh.  100044471918044
# 112  Đài Phát Thanh.  100044471918044
# 113  Đài Phát Thanh.  100044471918044
# 114  Đài Phát Thanh.  100044471918044
# 115  Đài Phát Thanh.  100044471918044
#
#                                               user_url
# 0    https://facebook.com/daiphatthanh.sound?lst=10...
# 1    https://facebook.com/daiphatthanh.sound?lst=10...
# 2    https://facebook.com/daiphatthanh.sound?lst=10...
# 3    https://facebook.com/daiphatthanh.sound?lst=10...
# 4    https://facebook.com/daiphatthanh.sound?lst=10...
# ..                                                 ...
# 111  https://facebook.com/daiphatthanh.sound?eav=Af...
# 112  https://facebook.com/daiphatthanh.sound?eav=Af...
# ...

# %%
# df.drop(['username','user_id','user_url'], axis='columns', inplace=True)

# %%
[['image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description']]
# Out:
# [['image_lowquality',
#   'images',
#   'images_description',
#   'images_lowquality',
#   'images_lowquality_description']]

# %%
df[['image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description']]
# cac bai dau tien thuong hay bi none va ko co du lieu dung.
# day la cac thong tin kha huu ich
# Out:
#                                       image_lowquality  \
# 0    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 1    https://scontent.fhan2-4.fna.fbcdn.net/v/t15.5...
# 2    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 3    https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 4    https://scontent.fhan2-4.fna.fbcdn.net/v/t39.3...
# ..                                                 ...
# 111  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 112  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# 113  https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 114  https://scontent.fhan2-4.fna.fbcdn.net/v/t39.3...
# 115  https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
#
#                                                 images  \
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3    ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
# ...

# %%
arr = np.array(df[['images_lowquality_description','images_description']].iloc[5])
arr
# du lieu 2 cot nay nhu nhau --> chon du lai 1 cot.
# Out:
# array(['["Có thể là hình ảnh về văn bản cho biết \'ĐÀI PHÁT THANH. TOlIS QuỳLnTinhNghị‹ch KHỞI CHIẾU 7.11 QUỲ LÙN TINH NGHỊCH: ĐỒNG TÂM HIỆP NHẠC QUY TỤ NHÓM NHẠC ĐÌNH ĐÁM: NSYNC, NKOTB, BOYZONE, BOYZ-II-MEN, BACKSTREET BOYS, 98 DEGREES, NEW EDITION,...\'"]',
#        '["Có thể là hình ảnh về văn bản cho biết \'ĐÀI PHÁT THANH. TOlIS QuỳLnTinhNghị‹ch KHỞI CHIẾU 7.11 QUỲ LÙN TINH NGHỊCH: ĐỒNG TÂM HIỆP NHẠC QUY TỤ NHÓM NHẠC ĐÌNH ĐÁM: NSYNC, NKOTB, BOYZONE, BOYZ-II-MEN, BACKSTREET BOYS, 98 DEGREES, NEW EDITION,...\'"]'],
#       dtype=object)

# %%
# df.drop(['images_lowquality_description'], axis='columns', inplace= True)

# %%
df[['images_lowquality','image_lowquality','images']]
# day chi la link anh vs .. --> khong quan trong co the xoa
# Out:
#                                      images_lowquality  \
# 0    ['https://scontent.fhan2-3.fna.fbcdn.net/v/t15...
# 1    ['https://scontent.fhan2-4.fna.fbcdn.net/v/t15...
# 2    ['https://scontent.fhan2-3.fna.fbcdn.net/v/t15...
# 3    ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
# 4    ['https://scontent.fhan2-4.fna.fbcdn.net/v/t39...
# ..                                                 ...
# 111  ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
# 112  ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
# 113  ['https://scontent.fhan2-3.fna.fbcdn.net/v/t15...
# 114  ['https://scontent.fhan2-4.fna.fbcdn.net/v/t39...
# 115  ['https://scontent.fhan2-3.fna.fbcdn.net/v/t39...
#
#                                       image_lowquality  \
# 0    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 1    https://scontent.fhan2-4.fna.fbcdn.net/v/t15.5...
# 2    https://scontent.fhan2-3.fna.fbcdn.net/v/t15.5...
# 3    https://scontent.fhan2-3.fna.fbcdn.net/v/t39.3...
# ...

# %% [markdown]
# was_live is_live

# %%
# df.drop(['images_lowquality','image_lowquality','images'], axis= 'columns', inplace= True)

# %%
df[['was_live','is_live']]
# nhu nhau --> false --> co the xoa.
# Out:
#      was_live  is_live
# 0       False    False
# 1       False    False
# 2       False    False
# 3       False    False
# 4       False    False
# ..        ...      ...
# 111     False    False
# 112     False    False
# 113     False    False
# 114     False    False
# 115     False    False
#
# [115 rows x 2 columns]

# %%
# df.drop(['was_live','is_live'], axis='columns', inplace=True)

# %% [markdown]
# cot cos : url va id
# - 'post_id','post_url','links','user_id','user_url','w3_fb_url','reactions','page_id','image_ids'

# %%
df[['post_id','post_url','links','user_id','user_url','w3_fb_url',
    'page_id','image_ids']].iloc[10]
# day la link va url id cua bai viet ko quan trong lam
# du lai post id
# Out:
# post_id                                        907547190737670
# post_url     https://facebook.com/daiphatthanh.sound/posts/...
# links        [{'link': '/story.php?story_fbid=pfbid02PEb6oU...
# user_id                                        100044471918044
# user_url     https://facebook.com/daiphatthanh.sound?eav=Af...
# w3_fb_url    https://www.facebook.com/daiphatthanh.sound/po...
# page_id                                        905871509607608
# image_ids                                                   []
# Name: 10, dtype: object

# %%
df['image_ids'].value_counts()
# Out:
# image_ids
# []                     74
# ['904559461036443']     1
# ['905197937639262']     1
# ['905179080974481']     1
# ['905078467651209']     1
# ['905114567647599']     1
# ['905115690980820']     1
# ['904945670997822']     1
# ['904926157666440']     1
# ['904632887695767']     1
# ['904465847712471']     1
# ['907693094056413']     1
# ['904460087713047']     1
# ['904448541047535']     1
# ['904425264383196']     1
# ['904349457724110']     1
# ['903934244432298']     1
# ['903921277766928']     1
# ['903943557764700']     1
# ['903783554447367']     1
# ['905416544284068']     1
# ['905490244276698']     1
# ['905532587605797']     1
# ['905555080936881']     1
# ['907724084053314']     1
# ['907635197395536']     1
# ['907613654064357']     1
# ['907253607433695']     1
# ['907243257434730']     1
# ['907205247438531']     1
# ['907109850781404']     1
# ['907076424118080']     1
# ['907045840787805']     1
# ['906689900823399']     1
# ['906664444159278']     1
# ...

# %% [markdown]
# comments_full , comments

# %%
df[['comments_full','comments']].iloc[10]
# Out:
# comments_full    [{'comment_id': '354418653911423', 'comment_ur...
# comments                                                        29
# Name: 10, dtype: object

# %%
arr = np.array(df['comments_full'].iloc[10])
arr
# comment full chua nhieu thong tin quan trong
# Out:
# array("[{'comment_id': '354418653911423', 'comment_url': 'https://facebook.com/354418653911423', 'commenter_id': '100047462205419', 'commenter_url': 'https://facebook.com/profile.php?id=100047462205419&eav=Afa8cC0uAQtajuWDj1lNpoagjjGPbIHR2UM3Uo26DGY2WnqzhEz7lVwPHelEp62BAGU&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Hoàng Yến', 'commenter_meta': 'Fan cứng', 'comment_text': 'Mê cái cách ả ta flex bồ 😚', 'comment_time': datetime.datetime(2023, 11, 9, 0, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '347978451115104', 'comment_url': 'https://facebook.com/347978451115104', 'commenter_id': '100034464938563', 'commenter_url': 'https://facebook.com/profile.php?id=100034464938563&eav=AfavESWRBZZIiFZz-YXpb1DTOBDj8U-_R5t-jna7uQ5okzc0K2gkPqLBCZE4snHricw&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Nguyễn Hoà', 'commenter_meta': None, 'comment_text': 'tay lỏ sờ wít này bé
# ...

# %%
arr = np.array(df['comments'].iloc[6])
arr
# so luong comment trong 1 bai viet.
# Out:
# array(131, dtype=int64)

# %% [markdown]
# time : time  timestamp fetched_time

# %%
df[['time','timestamp', 'fetched_time']]
# timestamp y nghia la gi ? 
# fetched_time : thoi gian lay du lieu -> khong quan trong co the xoa
# Out:
#                     time   timestamp                fetched_time
# 0    2023-11-15 22:02:13  1700060533  2023-11-15 22:14:38.058736
# 1    2023-11-15 21:30:56  1700058656  2023-11-15 22:14:42.149667
# 2    2023-11-15 20:32:56  1700055176  2023-11-15 22:14:57.035642
# 3    2023-11-15 20:06:52  1700053612  2023-11-15 22:15:27.113620
# 4    2023-11-15 19:38:51  1700051931  2023-11-15 22:16:31.727766
# ..                   ...         ...                         ...
# 111  2023-11-08 18:24:26  1699442666  2023-11-15 22:59:46.953222
# 112  2023-11-08 17:56:14  1699440974  2023-11-15 23:00:00.707447
# 113  2023-11-08 12:34:41  1699421681  2023-11-15 23:00:44.244203
# 114  2023-11-08 09:30:34  1699410634  2023-11-15 23:01:18.614700
# 115  2023-11-07 22:51:39  1699372299  2023-11-15 23:02:03.683482
#
# [115 rows x 3 columns]

# %% [markdown]
# Reaction

# %%
df[['reaction_count','reactions']]
# quan trong
# Out:
#      reaction_count                                          reactions
# 0                13                      {'thích': 11, 'yêu thích': 2}
# 1              1304  {'thích': 887, 'yêu thích': 402, 'haha': 3, 'w...
# 2               234  {'thích': 180, 'yêu thích': 52, 'haha': 1, 'th...
# 3             12435  {'thích': 8236, 'yêu thích': 260, 'haha': 3898...
# 4              4565  {'thích': 2235, 'yêu thích': 26, 'haha': 2289,...
# ..              ...                                                ...
# 111            3201  {'thích': 3180, 'yêu thích': 13, 'haha': 7, 't...
# 112            7399  {'thích': 5222, 'yêu thích': 119, 'haha': 2005...
# 113            9349  {'thích': 3722, 'yêu thích': 87, 'haha': 5509,...
# 114           23534  {'thích': 5926, 'yêu thích': 37, 'haha': 15854...
# 115           26676  {'thích': 17635, 'yêu thích': 8638, 'haha': 11...
#
# [115 rows x 2 columns]

# %% [markdown]
# text

# %%
df[['post_text','text']]
# Out:
#                                              post_text  \
# 0    Vũ Trụ Người Nhện của Sony chào đón phim dành ...
# 1    Khi Từng Quen còn chưa hết hot và Bé Ơi Từ Từ ...
# 2    Ca khúc có giai điệu cực đáng iu cho mùa noel ...
# 3    Về miền tây ăn đám cưới miệt vườn của Gin Tuấn...
# 4    Outfit chuẩn bị ăn cưới miệt vườn của Puka - G...
# ..                                                 ...
# 111  THÙY TIÊN DẠO NÀY: COSPLAY CAROL DANVERS, KHOE...
# 112  CHIẾC BMW TRỊ GIÁ HƠN 4 TỎI ĐƯA G-DRAGON ĐẾN T...
# 113  Talkshow chuyện nhà hot gơn Tây Hồ, vẫn là chủ...
# 114  ĐỘC LẠ DOUYIN TRUNG HOA\n\n"Chàng trai Trung Q...
# 115  HÃY TRÂN TRỌNG CÔ GÁI Ở BÊN CẠNH BẠN KHI BẠN K...
#
#                                                   text
# 0    Vũ Trụ Người Nhện của Sony chào đón phim dành ...
# 1    Khi Từng Quen còn chưa hết hot và Bé Ơi Từ Từ ...
# 2    Ca khúc có giai điệu cực đáng iu cho mùa noel ...
# 3    Về miền tây ăn đám cưới miệt vườn của Gin Tuấn...
# ...

# %%
df['post_text'] == df['text']
# xoa di post_text
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 111    True
# 112    True
# 113    True
# 114    True
# 115    True
# Length: 115, dtype: bool

# %%
df['available']
# xoa ko quan trong
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 111    True
# 112    True
# 113    True
# 114    True
# 115    True
# Name: available, Length: 115, dtype: bool

# %% [markdown]
# drop column

# %%
df.drop(['username','post_url','user_id','user_url','w3_fb_url','available','links',
         'page_id','image_ids','images_lowquality_description','images_lowquality',
         'image_lowquality','images','was_live','is_live','fetched_time','text']
         ,axis='columns',inplace=True)

# %% [markdown]
# Luu file da xu ly vao file.csv moi

# %%
FANPAGE_LINK ="Data_dpt"
FOLDER_PATH = r"Data/"
path=FOLDER_PATH + FANPAGE_LINK + ".csv"

# %%
df.to_csv(path, index=False)
print(path)
# Out:
# Data/Data_dpt.csv
