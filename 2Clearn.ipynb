# %% [markdown]
# <img src="https:////scontent.fhan9-1.fna.fbcdn.net/v/t39.30808-6/339122927_1347965006053141_1323654940389313527_n.jpg?_nc_cat=1&ccb=1-7&_nc_sid=5f2048&_nc_ohc=RxgK2wQBdfIAX9RQ12B&_nc_ht=scontent.fhan9-1.fna&oh=00_AfBOx5rlfgrGYgo-aGWT946hcP3U0n2WBaCcYTFM6OyZww&oe=65506ED3"
#     style="width:500px; float: right; margin: 0 40px 40px 40px;"></img>
#
# ##  PHÂN TÍCH DỮ LIỆU PAGE [đài phát thanh](https://www.facebook.com/daiphatthanh.sound)
# ## Bài phân viết phân tích page được viết trong [NOTION](https://www.notion.so/Data-Analyze-Page-Facebook-6ba0209824a04832b291f084f583f6b9).
#
# [hướng dẫn viết markdown](https://www.markdowntutorial.com/lesson/3/)
# Làm sạch dữ liệu: Dữ liệu thu thập ở bước 2 thường chứa nhiều khuyết thiếu
# đến từ lỗi của công cụ thu thập hay bản thân bài đăng trên Fanpage (chẳng
# hạn bài đăng không chứa nội dung, chưa có bình luận, hạn chế quyền truy cập
# bởi token, . . . ). Do vậy, sinh viên cần xem xét dữ liệu thô mình đã thu thập
# để loại bỏ đi các thông tin không liên quan hoặc không cần thiết trong bộ dữ
# liệu.

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ### Import thư viện và data.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv(r'Data\Data_28-11.csv')

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ## Phan tich du lieu tho
# đây là dữ liệu thô chưa được xử lý.

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        205 non-null    int64
#  1   text                           204 non-null    object
#  2   post_text                      204 non-null    object
#  3   shared_text                    0 non-null      float64
#  4   original_text                  0 non-null      float64
#  5   time                           205 non-null    object
#  6   timestamp                      205 non-null    float64
#  7   image                          146 non-null    object
#  8   image_lowquality               205 non-null    object
#  9   images                         205 non-null    object
#  10  images_description             205 non-null    object
#  11  images_lowquality              205 non-null    object
#  12  images_lowquality_description  205 non-null    object
#  13  video                          57 non-null     object
#  14  video_duration_seconds         0 non-null      float64
#  15  video_height                   0 non-null      float64
#  16  video_id                       57 non-null     float64
#  17  video_quality                  0 non-null      float64
#  18  video_size_MB                  0 non-null      float64
#  19  video_thumbnail                57 non-null     object
#  20  video_watches                  0 non-null      float64
#  21  video_width                    0 non-null      float64
#  22  likes                          205 non-null    int64
#  23  comments                       205 non-null    int64
#  24  shares                         205 non-null    int64
#  25  post_url                       205 non-null    object
#  26  link                           0 non-null      float64
#  27  links                          205 non-null    object
#  28  user_id                        205 non-null    int64
#  29  username                       205 non-null    object
#  30  user_url                       205 non-null    object
#  31  is_live                        205 non-null    bool
#  32  factcheck                      0 non-null      float64
#  33  shared_post_id                 0 non-null      float64
#  34  shared_time                    0 non-null      float64
#  35  shared_user_id                 0 non-null      float64
#  36  shared_username                0 non-null      float64
#  37  shared_post_url                0 non-null      float64
#  38  available                      205 non-null    bool
#  39  comments_full                  205 non-null    object
#  40  reactors                       205 non-null    object
#  41  w3_fb_url                      205 non-null    object
#  42  reactions                      205 non-null    object
#  43  reaction_count                 205 non-null    int64
#  44  with                           0 non-null      float64
#  45  page_id                        205 non-null    int64
#  46  sharers                        0 non-null      float64
#  47  image_id                       84 non-null     float64
#  48  image_ids                      205 non-null    object
#  49  was_live                       205 non-null    bool
#  50  fetched_time                   205 non-null    object
#  51  video_ids                      20 non-null     object
#  52  videos                         20 non-null     object
# dtypes: bool(3), float64(20), int64(7), object(23)
# memory usage: 80.8+ KB

# %%
raw_df.describe() # giá trị này sẽ ko chuẩn vì data chưa được xử lý.
# Out:
#             post_id  shared_text  original_text     timestamp  \
# count  2.050000e+02          0.0            0.0  2.050000e+02
# mean   9.097109e+14          NaN            NaN  1.700493e+09
# std    9.216860e+12          NaN            NaN  4.014843e+05
# min    7.827899e+14          NaN            NaN  1.699768e+09
# 25%    9.081688e+14          NaN            NaN  1.700133e+09
# 50%    9.106398e+14          NaN            NaN  1.700545e+09
# 75%    9.123574e+14          NaN            NaN  1.700835e+09
# max    9.141975e+14          NaN            NaN  1.701148e+09
#
#        video_duration_seconds  video_height      video_id  video_quality  \
# count                     0.0           0.0  5.700000e+01            0.0
# mean                      NaN           NaN  1.424218e+15            NaN
# std                       NaN           NaN  1.790871e+15            NaN
# min                       NaN           NaN  1.786545e+14            NaN
# 25%                       NaN           NaN  3.757239e+14            NaN
# 50%                       NaN           NaN  8.936109e+14            NaN
# 75%                       NaN           NaN  1.412643e+15            NaN
# max                       NaN           NaN  7.797883e+15            NaN
#
#        video_size_MB  video_watches  ...  shared_post_id  shared_time  \
# count            0.0            0.0  ...             0.0          0.0
# mean             NaN            NaN  ...             NaN          NaN
# std              NaN            NaN  ...             NaN          NaN
# min              NaN            NaN  ...             NaN          NaN
# 25%              NaN            NaN  ...             NaN          NaN
# 50%              NaN            NaN  ...             NaN          NaN
# 75%              NaN            NaN  ...             NaN          NaN
# max              NaN            NaN  ...             NaN          NaN
#
#        shared_user_id  shared_username  shared_post_url  reaction_count  with  \
# count             0.0              0.0              0.0      205.000000   0.0
# mean              NaN              NaN              NaN     8333.185366   NaN
# std               NaN              NaN              NaN    10984.954215   NaN
# min               NaN              NaN              NaN       64.000000   NaN
# 25%               NaN              NaN              NaN     2038.000000   NaN
# 50%               NaN              NaN              NaN     4457.000000   NaN
# 75%               NaN              NaN              NaN    10585.000000   NaN
# max               NaN              NaN              NaN    82515.000000   NaN
#
#             page_id  sharers      image_id
# count  2.050000e+02      0.0  8.400000e+01
# mean   9.058715e+14      NaN  9.087703e+14
# std    4.886934e+00      NaN  1.409240e+13
# min    9.058715e+14      NaN  7.827899e+14
# 25%    9.058715e+14      NaN  9.082147e+14
# 50%    9.058715e+14      NaN  9.104404e+14
# 75%    9.058715e+14      NaN  9.121767e+14
# max    9.058715e+14      NaN  9.141513e+14
#
# [8 rows x 27 columns]

# %%
raw_df.isnull()
# Out:
#      post_id   text  post_text  shared_text  original_text   time  timestamp  \
# 0      False  False      False         True           True  False      False
# 1      False  False      False         True           True  False      False
# 2      False  False      False         True           True  False      False
# 3      False  False      False         True           True  False      False
# 4      False  False      False         True           True  False      False
# ..       ...    ...        ...          ...            ...    ...        ...
# 200    False  False      False         True           True  False      False
# 201    False  False      False         True           True  False      False
# 202    False  False      False         True           True  False      False
# 203    False  False      False         True           True  False      False
# 204    False  False      False         True           True  False      False
#
#      image  image_lowquality  images  ...  reaction_count  with  page_id  \
# 0     True             False   False  ...           False  True    False
# 1    False             False   False  ...           False  True    False
# 2    False             False   False  ...           False  True    False
# 3     True             False   False  ...           False  True    False
# 4     True             False   False  ...           False  True    False
# ..     ...               ...     ...  ...             ...   ...      ...
# 200   True             False   False  ...           False  True    False
# 201   True             False   False  ...           False  True    False
# 202   True             False   False  ...           False  True    False
# 203  False             False   False  ...           False  True    False
# 204  False             False   False  ...           False  True    False
#
#      sharers  image_id  image_ids  was_live  fetched_time  video_ids  videos
# 0       True      True      False     False         False       True    True
# 1       True      True      False     False         False       True    True
# 2       True     False      False     False         False       True    True
# 3       True      True      False     False         False       True    True
# 4       True      True      False     False         False       True    True
# ..       ...       ...        ...       ...           ...        ...     ...
# 200     True      True      False     False         False       True    True
# 201     True      True      False     False         False       True    True
# 202     True      True      False     False         False       True    True
# 203     True      True      False     False         False      False   False
# 204     True     False      False     False         False       True    True
#
# [205 rows x 53 columns]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# # Thuc hien danh gia cac cot

# %% [markdown]
# dữ liệu được lấy từ ngày.

# %%
raw_df['time'].head(1)
# Out:
# 0    2023-11-28 11:58:32
# Name: time, dtype: object

# %%
data = pd.DataFrame(raw_df[['post_id','text','post_text','time','timestamp','image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description','comments','shares',
       'post_url','links','user_id','username','user_url','is_live','available','comments_full',
       'reactors','w3_fb_url','reactions','reaction_count','page_id','image_ids',
       'was_live','fetched_time']])
data
# Out:
#              post_id                                               text  \
# 0    914197540072635  Dù là một nữ idol thì Jiyeon (T-ara) vẫn sẽ là...
# 1    914174400074949  ĐỘ TỘC XÂY TRƯỜNG ĐƯỢC RỒI!\r\n\r\nSáng 25/11,...
# 2    914151560077233  Khi bạn là rapper mainstream nhưng vẫn muốn gi...
# 3    913951943430528  Thái VG trở lại với Andy Vũ trong MV "Điếc", d...
# 4    913920416767014  Hoàng Thuỳ Linh và Đen cực tình tứ trong MV mớ...
# ..               ...                                                ...
# 200  906122894213433  Mùa 1 The Masked Singer có ‘Anh Thương Em Đến ...
# 201  906132410879148  Có một Việt Nam cổ kính, hoài niệm cùng chuyện...
# 202  906147284210994  Nguyên Hà trở lại với sản phẩm mới mang tên "N...
# 203  906040377555018  Chị đẹp HyunA “xả ảnh”, khoe những món quà đán...
# 204  906017847557271  Bác Nguyễn Ngọc Giao là bố của Nodey - chồng S...
#
#                                              post_text                 time  \
# 0    Dù là một nữ idol thì Jiyeon (T-ara) vẫn sẽ là...  2023-11-28 11:58:32
# 1    ĐỘ TỘC XÂY TRƯỜNG ĐƯỢC RỒI!\r\n\r\nSáng 25/11,...  2023-11-28 10:53:40
# 2    Khi bạn là rapper mainstream nhưng vẫn muốn gi...  2023-11-28 09:48:24
# 3    Thái VG trở lại với Andy Vũ trong MV "Điếc", d...  2023-11-27 23:59:52
# 4    Hoàng Thuỳ Linh và Đen cực tình tứ trong MV mớ...  2023-11-27 22:46:26
# ..                                                 ...                  ...
# 200  Mùa 1 The Masked Singer có ‘Anh Thương Em Đến ...  2023-11-12 20:00:49
# 201  Có một Việt Nam cổ kính, hoài niệm cùng chuyện...  2023-11-12 19:30:33
# 202  Nguyên Hà trở lại với sản phẩm mới mang tên "N...  2023-11-12 19:02:54
# 203  Chị đẹp HyunA “xả ảnh”, khoe những món quà đán...  2023-11-12 13:43:43
# 204  Bác Nguyễn Ngọc Giao là bố của Nodey - chồng S...  2023-11-12 12:46:22
#
#         timestamp                                   image_lowquality  \
# 0    1.701148e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 1    1.701144e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 2    1.701140e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 3    1.701104e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 4    1.701100e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# ..            ...                                                ...
# 200  1.699794e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 201  1.699792e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 202  1.699791e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 203  1.699771e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 204  1.699768e+09  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
#
#                                                 images  \
# 0                                                   []
# 1    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 200                                                 []
# 201                                                 []
# 202                                                 []
# 203  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 204  ['https://m.facebook.com/photo/view_full_size/...
#
#                                     images_description  \
# 0                                                   []
# 1    ["Có thể là hình ảnh về 1 người, khăn quàng cổ...
# 2    ['May be an image of 1 person, frisbee, grass ...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 200                                                 []
# 201                                                 []
# 202                                                 []
# 203  ['May be a doodle of text', 'May be an image o...
# 204  ['May be an image of 2 people and text that sa...
#
#                                      images_lowquality  \
# 0    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 1    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 4    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# ..                                                 ...
# 200  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 201  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 202  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 203  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 204  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
#
#                          images_lowquality_description  ...  available  \
# 0                                               [None]  ...       True
# 1    ["Có thể là hình ảnh về 1 người, khăn quàng cổ...  ...       True
# 2    ['May be an image of 1 person, frisbee, grass ...  ...       True
# 3                                               [None]  ...       True
# 4                                               [None]  ...       True
# ..                                                 ...  ...        ...
# 200                                             [None]  ...       True
# 201                                             [None]  ...       True
# 202                                             [None]  ...       True
# 203  ['May be a doodle of text', 'May be an image o...  ...       True
# 204  ['May be an image of 2 people and text that sa...  ...       True
#
#                                          comments_full  \
# 0    [{'comment_id': '1039836823726352', 'comment_u...
# 1    [{'comment_id': '368548022246931', 'comment_ur...
# 2    [{'comment_id': '312559144928576', 'comment_ur...
# 3    [{'comment_id': '817493280133374', 'comment_ur...
# 4    [{'comment_id': '851805823393898', 'comment_ur...
# ..                                                 ...
# 200  [{'comment_id': '1479523686164818', 'comment_u...
# 201  [{'comment_id': '355506063680878', 'comment_ur...
# 202  [{'comment_id': '350900500809472', 'comment_ur...
# 203  [{'comment_id': '1084543082512822', 'comment_u...
# 204  [{'comment_id': '729995859155483', 'comment_ur...
#
#                                               reactors  \
# 0                                                   []
# 1    [{'name': 'Lê Ngọc Phát', 'link': 'https://fac...
# 2    [{'name': 'Minh Phương', 'link': 'https://face...
# 3    [{'name': 'Hù NG', 'link': 'https://facebook.c...
# 4    [{'name': 'Trúc Tre', 'link': 'https://faceboo...
# ..                                                 ...
# 200  [{'name': 'Quynh Anh', 'link': 'https://facebo...
# 201  [{'name': 'Bảo Trân', 'link': 'https://faceboo...
# 202  [{'name': 'Quyền Đăng', 'link': 'https://faceb...
# 203  [{'name': 'Quynh Huong', 'link': 'https://face...
# 204  [{'name': 'Như Ý Nt', 'link': 'https://faceboo...
#
#                                              w3_fb_url  \
# 0    https://www.facebook.com/daiphatthanh.sound/po...
# 1    https://www.facebook.com/daiphatthanh.sound/po...
# 2    https://www.facebook.com/daiphatthanh.sound/po...
# 3    https://www.facebook.com/daiphatthanh.sound/po...
# 4    https://www.facebook.com/daiphatthanh.sound/po...
# ..                                                 ...
# 200  https://www.facebook.com/daiphatthanh.sound/po...
# 201  https://www.facebook.com/daiphatthanh.sound/po...
# 202  https://www.facebook.com/daiphatthanh.sound/po...
# 203  https://www.facebook.com/daiphatthanh.sound/po...
# 204  https://www.facebook.com/daiphatthanh.sound/po...
#
#                                              reactions reaction_count  \
# 0      {'like': 88, 'love': 18, 'haha': 16, 'care': 1}            123
# 1    {'like': 2805, 'love': 1004, 'haha': 7, 'wow':...           3845
# 2    {'like': 2877, 'love': 30, 'haha': 935, 'wow':...           3864
# 3    {'like': 1394, 'love': 268, 'haha': 17, 'wow':...           1687
# 4    {'like': 843, 'love': 191, 'haha': 4, 'wow': 1...           1044
# ..                                                 ...            ...
# 200  {'like': 6042, 'love': 2339, 'haha': 10, 'wow'...           8492
# 201  {'like': 1722, 'love': 714, 'haha': 1, 'care':...           2450
# 202  {'like': 1704, 'love': 322, 'haha': 4, 'care':...           2038
# 203  {'like': 4299, 'love': 1770, 'haha': 14, 'wow'...           6128
# 204  {'like': 1863, 'love': 426, 'haha': 5, 'wow': ...           2340
#
#              page_id            image_ids  was_live  \
# 0    905871509607608                   []     False
# 1    905871509607608                   []     False
# 2    905871509607608  ['914151330077256']     False
# 3    905871509607608                   []     False
# 4    905871509607608                   []     False
# ..               ...                  ...       ...
# 200  905871509607608                   []     False
# 201  905871509607608                   []     False
# 202  905871509607608                   []     False
# 203  905871509607608                   []     False
# 204  905871509607608  ['906024567556599']     False
#
#                    fetched_time
# 0    2023-11-28 12:12:38.515789
# 1    2023-11-28 12:12:54.455377
# 2    2023-11-28 12:13:30.300311
# 3    2023-11-28 12:13:55.055524
# 4    2023-11-28 12:14:05.726693
# ..                          ...
# 200  2023-11-24 15:15:06.705651
# 201  2023-11-24 15:15:51.925781
# 202  2023-11-24 15:16:07.242082
# 203  2023-11-24 15:16:26.953292
# 204  2023-11-24 15:16:41.044241
#
# [205 rows x 28 columns]

# %% [markdown]
# Cac du lieu lien quan den uses la nhu nhau trong moi bai post.
# - suy ra ko can thiet lay

# %%
data[['username','user_id','user_url']].head(1)
# Out:
#           username          user_id  \
# 0  Đài Phát Thanh.  100044471918044
#
#                                             user_url
# 0  https://facebook.com/daiphatthanh.sound?lst=10...

# %% [markdown]
# Du lieu ve image
# - day la thong tin quan trong

# %%
data[['image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description']].head(1)
# Out:
#                                     image_lowquality images  \
# 0  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...     []
#
#   images_description                                  images_lowquality  \
# 0                 []  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
#
#   images_lowquality_description
# 0                        [None]

# %%
data['images_description'].iloc[7]
# Out:
# "['May be an image of 2 people', 'May be an image of 4 people', 'May be an image of 1 person and plaits', 'May be an image of 6 people']"

# %% [markdown]
# is live

# %%
data['is_live'].count
# khong can thiet lay
# Out:
# <bound method Series.count of 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: is_live, Length: 205, dtype: bool>

# %%
display(
    data.shape,
    data.dtypes
)
# Out:
# (205, 28)
# post_id                            int64
# text                              object
# post_text                         object
# time                              object
# timestamp                        float64
# image_lowquality                  object
# images                            object
# images_description                object
# images_lowquality                 object
# images_lowquality_description     object
# comments                           int64
# shares                             int64
# post_url                          object
# links                             object
# user_id                            int64
# username                          object
# user_url                          object
# is_live                             bool
# available                           bool
# comments_full                     object
# reactors                          object
# w3_fb_url                         object
# reactions                         object
# reaction_count                     int64
# page_id                            int64
# image_ids                         object
# was_live                            bool
# fetched_time                      object
# dtype: object

# %% [markdown]
# Vì yêu cầu đề bài là lấy 100 bài. Mà data đã có đủ nên không cần xử lý nhiều
# Trực tiếp lấy dữ liệu các dòng có thể dùng được.

# %%
df = pd.DataFrame(data= data.dropna(how='any'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 204 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   post_id                        204 non-null    int64
#  1   text                           204 non-null    object
#  2   post_text                      204 non-null    object
#  3   time                           204 non-null    object
#  4   timestamp                      204 non-null    float64
#  5   image_lowquality               204 non-null    object
#  6   images                         204 non-null    object
#  7   images_description             204 non-null    object
#  8   images_lowquality              204 non-null    object
#  9   images_lowquality_description  204 non-null    object
#  10  comments                       204 non-null    int64
#  11  shares                         204 non-null    int64
#  12  post_url                       204 non-null    object
#  13  links                          204 non-null    object
#  14  user_id                        204 non-null    int64
#  15  username                       204 non-null    object
#  16  user_url                       204 non-null    object
#  17  is_live                        204 non-null    bool
#  18  available                      204 non-null    bool
#  19  comments_full                  204 non-null    object
#  20  reactors                       204 non-null    object
#  21  w3_fb_url                      204 non-null    object
#  22  reactions                      204 non-null    object
#  23  reaction_count                 204 non-null    int64
#  24  page_id                        204 non-null    int64
#  25  image_ids                      204 non-null    object
#  26  was_live                       204 non-null    bool
#  27  fetched_time                   204 non-null    object
# dtypes: bool(3), float64(1), int64(6), object(18)
# memory usage: 42.0+ KB

# %% [markdown]
# Kiểm tra số lượng tương tác trong nhưng bài mới đăng tải
# - vì số lượng người tương tác ko ổn định

# %%
df[['post_id','time','reactions','comments','shares','reactors']].head()
# Out:
#            post_id                 time  \
# 0  914197540072635  2023-11-28 11:58:32
# 1  914174400074949  2023-11-28 10:53:40
# 2  914151560077233  2023-11-28 09:48:24
# 3  913951943430528  2023-11-27 23:59:52
# 4  913920416767014  2023-11-27 22:46:26
#
#                                            reactions  comments  shares  \
# 0    {'like': 88, 'love': 18, 'haha': 16, 'care': 1}         4       4
# 1  {'like': 2805, 'love': 1004, 'haha': 7, 'wow':...        20      11
# 2  {'like': 2877, 'love': 30, 'haha': 935, 'wow':...        54      44
# 3  {'like': 1394, 'love': 268, 'haha': 17, 'wow':...        17      32
# 4  {'like': 843, 'love': 191, 'haha': 4, 'wow': 1...        20      32
#
#                                             reactors
# 0                                                 []
# 1  [{'name': 'Lê Ngọc Phát', 'link': 'https://fac...
# 2  [{'name': 'Minh Phương', 'link': 'https://face...
# 3  [{'name': 'Hù NG', 'link': 'https://facebook.c...
# 4  [{'name': 'Trúc Tre', 'link': 'https://faceboo...

# %% [markdown]
# [['username','user_id','user_url']]

# %%
df[['username','user_id','user_url']].head()
# du lieu nhu nhau khong can thiet
# Out:
#           username          user_id  \
# 0  Đài Phát Thanh.  100044471918044
# 1  Đài Phát Thanh.  100044471918044
# 2  Đài Phát Thanh.  100044471918044
# 3  Đài Phát Thanh.  100044471918044
# 4  Đài Phát Thanh.  100044471918044
#
#                                             user_url
# 0  https://facebook.com/daiphatthanh.sound?lst=10...
# 1  https://facebook.com/daiphatthanh.sound?lst=10...
# 2  https://facebook.com/daiphatthanh.sound?lst=10...
# 3  https://facebook.com/daiphatthanh.sound?lst=10...
# 4  https://facebook.com/daiphatthanh.sound?lst=10...

# %%
df[['image_lowquality','images','images_description',
       'images_lowquality','images_lowquality_description']].head()
# cac bai dau tien thuong hay bi none va ko co du lieu dung.
# day la cac thong tin kha huu ich
# Out:
#                                     image_lowquality  \
# 0  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 1  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 2  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 3  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 4  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
#
#                                               images  \
# 0                                                 []
# 1  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3                                                 []
# 4                                                 []
#
#                                   images_description  \
# 0                                                 []
# 1  ["Có thể là hình ảnh về 1 người, khăn quàng cổ...
# 2  ['May be an image of 1 person, frisbee, grass ...
# 3                                                 []
# 4                                                 []
#
#                                    images_lowquality  \
# 0  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 1  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 4  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
#
#                        images_lowquality_description
# 0                                             [None]
# 1  ["Có thể là hình ảnh về 1 người, khăn quàng cổ...
# 2  ['May be an image of 1 person, frisbee, grass ...
# 3                                             [None]
# 4                                             [None]

# %%
arr = np.array(df[['images_lowquality_description','images_description']].iloc[5])
arr
# du lieu 2 cot nay nhu nhau --> chon du lai 1 cot.
# Out:
# array(["['May be an image of text']", '[]'], dtype=object)

# %%
df[['images_lowquality','image_lowquality','images']]
# day chi la link anh vs .. --> khong quan trong co the xoa
# Out:
#                                      images_lowquality  \
# 0    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 1    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 4    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# ..                                                 ...
# 200  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 201  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 202  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t15...
# 203  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 204  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
#
#                                       image_lowquality  \
# 0    https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 1    https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 2    https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 3    https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 4    https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# ..                                                 ...
# 200  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 201  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 202  https://scontent.fhan9-1.fna.fbcdn.net/v/t15.5...
# 203  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
# 204  https://scontent.fhan9-1.fna.fbcdn.net/v/t39.3...
#
#                                                 images
# 0                                                   []
# 1    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 2    ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 200                                                 []
# 201                                                 []
# 202                                                 []
# 203  ['https://scontent.fhan9-1.fna.fbcdn.net/v/t39...
# 204  ['https://m.facebook.com/photo/view_full_size/...
#
# [204 rows x 3 columns]

# %% [markdown]
# was_live is_live

# %%
df[['was_live','is_live']].head()
# nhu nhau --> false --> co the xoa.
# Out:
#    was_live  is_live
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %% [markdown]
# cot cos : url va id
# - 'post_id','post_url','links','user_id','user_url','w3_fb_url','reactions','page_id','image_ids'

# %%
df[['post_id','post_url','links','user_id','user_url','w3_fb_url',
    'page_id','image_ids']].iloc[10]
# day la link va url id cua bai viet ko quan trong lam
# du lai post id
# Out:
# post_id                                        913789500113439
# post_url     https://facebook.com/daiphatthanh.sound/posts/...
# links        [{'link': '/story.php?story_fbid=pfbid02fpdLtY...
# user_id                                        100044471918044
# user_url     https://facebook.com/daiphatthanh.sound?eav=Af...
# w3_fb_url    https://www.facebook.com/daiphatthanh.sound/po...
# page_id                                        905871509607608
# image_ids                                                   []
# Name: 10, dtype: object

# %%
df['image_ids'].value_counts()
# Out:
# image_ids
# []                     121
# ['909694633856259']      1
# ['908542763971446']      1
# ['908596217299434']      1
# ['908673010625088']      1
#                       ...
# ['911833660309023']      1
# ['912152360277153']      1
# ['912159080276481']      1
# ['912173313608391']      1
# ['906024567556599']      1
# Name: count, Length: 84, dtype: int64

# %% [markdown]
# comments_full , comments

# %%
df[['comments_full','comments']].iloc[10]
# Out:
# comments_full    [{'comment_id': '865005275163837', 'comment_ur...
# comments                                                        79
# Name: 10, dtype: object

# %%
arr = np.array(df['comments_full'].iloc[10])
arr
# comment full chua nhieu thong tin quan trong
# Out:
# array("[{'comment_id': '865005275163837', 'comment_url': 'https://facebook.com/865005275163837', 'commenter_id': '100085315680217', 'commenter_url': 'https://facebook.com/tllphuong?eav=Afa33s4Ip6QmkFoknmyZw9X8hMq-KqoRa9Ct7dXxq0mm6HyP82RIidhq9-rmsToFFVs&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Lan Phương', 'commenter_meta': None, 'comment_text': 'Phạm Uyên nữa nàyy haha', 'comment_time': datetime.datetime(2023, 11, 27, 16, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '1063844824768465', 'comment_url': 'https://facebook.com/1063844824768465', 'commenter_id': '100079033546470', 'commenter_url': 'https://facebook.com/profile.php?id=100079033546470&eav=AfY8EpJM9i9ivK88gd-YNeajNJgzfmKrrWOIFWtXA0crE6nTwvzfvM86FdBa8tFOXtc&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Pham Nguyen Son', 'commenter_meta': None, 'comment_text': 'Đúng Ecopark chịu chi thật, làm giáng sinh cho cư dân to thế', 'comment_time': datetime.datetime(2023, 11, 27, 9, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '319918987488761', 'comment_url': 'https://facebook.com/319918987488761', 'commenter_id': '100072483024586', 'commenter_url': 'https://facebook.com/profile.php?id=100072483024586&eav=AfaMVJnSSBfnY2BnNLbJTZ9T1PYKyuMvo_Jr4y2GJV_X_m2WYkDre3tgBZRzp5SXnOY&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Văn Toàn Ldol', 'commenter_meta': None, 'comment_text': 'tính ra 1 tháng chơi Noel như này đỡ bon chen', 'comment_time': datetime.datetime(2023, 11, 27, 10, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '1426513027935127', 'comment_url': 'https://facebook.com/1426513027935127', 'commenter_id': '100077690947253', 'commenter_url': 'https://facebook.com/profile.php?id=100077690947253&eav=AfbzgFfKAaE4jKJBDvaULOepSLhcvqqt2iTE-gJbKBccYagpANwhr9NO6c8GpYESYU8&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Hồng Nguyễn', 'commenter_meta': None, 'comment_text': 'Đang bảo sắp giáng sinh k biết cho tụi nhỏ đi chơi chỗ nào, may quá', 'comment_time': datetime.datetime(2023, 11, 27, 9, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': []}, {'comment_id': '3162241890737557', 'comment_url': 'https://facebook.com/3162241890737557', 'commenter_id': '100008545755420', 'commenter_url': 'https://facebook.com/itsmelilchic?eav=Afb2PaJCq-fDLgokdC96J7gYt0nUUXORHdVPKFdJIqS4hMKBkkvkgqsCAzaypQrixZo&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Hồng Yếnn', 'commenter_meta': None, 'comment_text': 'Việt Trung hii đến lúc đi Ecopark gòi ạaa =)))', 'comment_time': datetime.datetime(2023, 11, 27, 21, 0), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None, 'replies': [{'comment_id': '231813209929728', 'comment_url': 'https://facebook.com/231813209929728', 'commenter_id': '100011280483425', 'commenter_url': 'https://facebook.com/trung.viet.33046?eav=AfbF3J7sF15alzBkwCuBql_BI7XjhesCJ4qzw8nu6s9SRvGtxc_Fe1Q702qccb29Hfk&fref=nf&rc=p&__tn__=R&paipv=0', 'commenter_name': 'Việt Trung', 'commenter_meta': None, 'comment_text': 'Hồng Yếnn okalee', 'comment_time': datetime.datetime(2023, 11, 27, 23, 12), 'comment_image': None, 'comment_reactors': [], 'comment_reactions': None, 'comment_reaction_count': None}]}, {'comment_id': '795550025714373', 'comment_url': 'https://facebook.com/795550025714373', 'commenter_id': '100011803153026', 'commenter_url': 'https://facebook.com/thanhtu7122?eav=AfYhz-g4VXIyuQ-V21AV9v3ugz3voQ3q-ZpAV3_cAWBFapsI5iemnSogxGozZnhYNxk&fref=nf&rc=p&refid=52&__tn__=R&paipv=0', 'commenter_name': 'Thanh Tú', 'commenter_meta': None, 'comment_text': 'Dieu Linh đẹp thiệt thì bảo nhé để có cớ sang =))))', 'comment_time': dateti ...
#       dtype='<U29660')

# %%
arr = np.array(df['comments'].iloc[6])
arr
# so luong comment trong 1 bai viet.
# Out:
# array(38, dtype=int64)

# %% [markdown]
# time : time  timestamp fetched_time

# %%
df[['time','timestamp', 'fetched_time']].head()
# timestamp y nghia la gi ? 
# fetched_time : thoi gian lay du lieu -> khong quan trong co the xoa
# Out:
#                   time     timestamp                fetched_time
# 0  2023-11-28 11:58:32  1.701148e+09  2023-11-28 12:12:38.515789
# 1  2023-11-28 10:53:40  1.701144e+09  2023-11-28 12:12:54.455377
# 2  2023-11-28 09:48:24  1.701140e+09  2023-11-28 12:13:30.300311
# 3  2023-11-27 23:59:52  1.701104e+09  2023-11-28 12:13:55.055524
# 4  2023-11-27 22:46:26  1.701100e+09  2023-11-28 12:14:05.726693

# %% [markdown]
# Reaction

# %%
df[['reaction_count','reactions']].head()
# quan trong
# Out:
#    reaction_count                                          reactions
# 0             123    {'like': 88, 'love': 18, 'haha': 16, 'care': 1}
# 1            3845  {'like': 2805, 'love': 1004, 'haha': 7, 'wow':...
# 2            3864  {'like': 2877, 'love': 30, 'haha': 935, 'wow':...
# 3            1687  {'like': 1394, 'love': 268, 'haha': 17, 'wow':...
# 4            1044  {'like': 843, 'love': 191, 'haha': 4, 'wow': 1...

# %% [markdown]
# text

# %%
df[['post_text','text']].head()
# Out:
#                                            post_text  \
# 0  Dù là một nữ idol thì Jiyeon (T-ara) vẫn sẽ là...
# 1  ĐỘ TỘC XÂY TRƯỜNG ĐƯỢC RỒI!\r\n\r\nSáng 25/11,...
# 2  Khi bạn là rapper mainstream nhưng vẫn muốn gi...
# 3  Thái VG trở lại với Andy Vũ trong MV "Điếc", d...
# 4  Hoàng Thuỳ Linh và Đen cực tình tứ trong MV mớ...
#
#                                                 text
# 0  Dù là một nữ idol thì Jiyeon (T-ara) vẫn sẽ là...
# 1  ĐỘ TỘC XÂY TRƯỜNG ĐƯỢC RỒI!\r\n\r\nSáng 25/11,...
# 2  Khi bạn là rapper mainstream nhưng vẫn muốn gi...
# 3  Thái VG trở lại với Andy Vũ trong MV "Điếc", d...
# 4  Hoàng Thuỳ Linh và Đen cực tình tứ trong MV mớ...

# %%
df['post_text'] == df['text']
# xoa di post_text
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 200    True
# 201    True
# 202    True
# 203    True
# 204    True
# Length: 204, dtype: bool

# %%
df['available'].head()
# xoa ko quan trong
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: available, dtype: bool

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ## thuc hien xoa cot khong can thiet

# %%
df.drop(['username','post_url','user_id','user_url','w3_fb_url','available','links',
         'page_id','image_ids','images_lowquality_description','images_lowquality',
         'image_lowquality','images','was_live','is_live','fetched_time','text']
         ,axis='columns',inplace=True)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
# ## Luu file da xu ly vao file.csv moi

# %%
FANPAGE_LINK ="Data_cleared"
FOLDER_PATH = r"Data/"
path=FOLDER_PATH + FANPAGE_LINK + ".csv"

# %%
df.to_csv(path, index=False)
print(path)
# Out:
# Data/Data_cleared.csv
